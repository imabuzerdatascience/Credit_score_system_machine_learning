# %% [markdown]
# <h1 align='center' style='color:blue'> Credit Risk Modeling Project</h1>

# %% [markdown]
# ### Import Necessary libraries

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load dtasets

# %%
df_customers = pd.read_csv("dataset/customers.csv")
df_loans = pd.read_csv("dataset/loans.csv")
df_bureau = pd.read_csv("dataset/bureau_data.csv")

# %%
print(f" customer : {df_customers.shape} , loans : {df_loans.shape} , bureau_data : {df_bureau.shape} " )
# Out:
#  customer : (50000, 12) , loans : (50000, 15) , bureau_data : (50000, 8)

# %%
df_customers.head(5)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans.sample(5)
# Out:
#       loan_id cust_id loan_purpose loan_type  sanction_amount  loan_amount  \
# 8874   L08875  C08875         Auto   Secured          3018000      2550000
# 43524  L43525  C43525         Home   Secured         34166000     24165000
# 3709   L03710  C03710         Home   Secured          2292000      1807000
# 30419  L30420  C30420         Home   Secured          6681000      5436000
# 19906  L19907  C19907         Home   Secured          7953000      7795000
#
#        processing_fee      gst  net_disbursement  loan_tenure_months  \
# 8874         51000.00   459000           2040000                  17
# 43524       483300.00  4349700          19332000                  33
# 3709         36140.00   325260           1445600                  32
# 30419       108720.00   978480           4348800                  45
# 19906       155900.00  1403100           6236000                  44
#
#        principal_outstanding  bank_balance_at_application disbursal_date  \
# 8874                 1673407                       669827     2020-06-12
# 43524                5000000                      2765782     2023-11-29
# 3709                  457222                       168695     2019-12-07
# 30419                1315788                      1151897     2022-08-07
# 19906                 935136                       557279     2021-07-20
#
#       installment_start_dt  default
# 8874            2020-06-18    False
# 43524           2023-12-20    False
# 3709            2020-01-06    False
# 30419           2022-08-26    False
# 19906           2021-08-11     True

# %%
df_bureau.tail(5)
# Out:
#       cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 49995  C49996                        4                          2
# 49996  C49997                        4                          0
# 49997  C49998                        4                          1
# 49998  C49999                        1                          2
# 49999  C50000                        2                          0
#
#        total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 49995                165                  1          6              8
# 49996                161                  0          0              4
# 49997                 42                  0          0              7
# 49998                 42                  9         47              4
# 49999                 65                 13         66              7
#
#        credit_utilization_ratio
# 49995                        24
# 49996                        91
# 49997                        38
# 49998                        17
# 49999                        28

# %% [markdown]
# ### Merge All Datasets

# %%
df = pd.merge(df_customers , df_loans , on="cust_id") 
df.head(5)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
# 3  ...     1747000        34940.00  314460          1397600
# 4  ...     4520000        90400.00  813600          3616000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
# 3                  6                1257839                      1031094
# 4                 28                1772334                      1032458
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
# 3      2019-07-24            2019-08-09    False
# 4      2019-07-24            2019-08-02    False
#
# [5 rows x 26 columns]

# %%
df = pd.merge(df, df_bureau , on="cust_id") 
df.head(5)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... total_dpd_x  enquiry_count_x credit_utilization_ratio_x  \
# 0  ...           0                3                          7
# 1  ...          60                5                          4
# 2  ...         147                6                         58
# 3  ...          87                5                         26
# 4  ...           0                5                         10
#
#   number_of_open_accounts_y number_of_closed_accounts_y  total_loan_months_y  \
# 0                         1                           1                   42
# 1                         3                           1                   96
# 2                         2                           1                   82
# 3                         3                           0                  115
# 4                         4                           2                  120
#
#    delinquent_months_y  total_dpd_y  enquiry_count_y  \
# 0                    0            0                3
# 1                   12           60                5
# 2                   24          147                6
# 3                   15           87                5
# 4                    0            0                5
#
#    credit_utilization_ratio_y
# 0                           7
# 1                           4
# 2                          58
# 3                          26
# 4                          10
#
# [5 rows x 40 columns]

# %%
df.shape
# Out:
# (50000, 40)
